# %%
# %load_ext autoreload
# %autoreload 2

from onboarding_utils import *

# %%
building_config='/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/ce_cdws_chws_10-29.yaml'
abel_config = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/ce_hydronic_pilot_abel_config.yaml'
dump_path = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/us-mtv-ce_onboard_update_reporting.yaml'

export_update_config(building_config, abel_config, dump_path, max_items=50)
# Out:
# 5 reporting entities found
# Added  3e29ca0e-76b2-4798-a4f0-499f11836c16
# Added  6eff99fd-25e1-4848-88d3-c1aa1156037e
# Added  85f42fb6-575c-457a-9b22-c9d0e31c7fba
# Added  90bc5f83-45d2-46d5-9e38-686201ef77ce
# Added  aca70ef3-479a-4fb1-ab58-dfe058af9d86
# Saving chunk 1, 5 entities.

# %%
building_config='/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/ce_cdws_chws_10-29_new_etags.yaml'
abel_config = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/ce_hydronic_pilot_abel_config.yaml'
dump_path = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/us-mtv-ce_onboard_update_rvirtual.yaml'

export_add_config(building_config, abel_config, dump_path)

# %%
building_config = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/ce_cdws_chws_10-29.yaml'
abel_config = '/usr/local/google/home/evgeniyaengel/Documents/hydronic-pilot/us-mtv-ce_onboard_update_reporting_pt1.yaml'

update_etags(building_config, abel_config)
