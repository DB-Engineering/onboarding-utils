# %%
from abel_convert_loadsheet import *

# %%
loadsheet_path = '/usr/local/google/home/evgeniyaengel/Downloads/US-MTV-1250 CRAC Units Onboarding.xlsx'
payload_path = '/usr/local/google/home/evgeniyaengel/Downloads/mtv1250_payload.csv'
dump_path = '/usr/local/google/home/evgeniyaengel/Downloads/US-MTV-1250_CRAC_Units_Onboarding.xlsx'

# %%
convert = Abel()
convert.import_loadsheet(loadsheet_path)
convert.import_payload(payload_path)
# convert.import_building_config(building_config)
convert.build()
convert.dump(dump_path)
