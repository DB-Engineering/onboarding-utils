# %%
from abel_convert_loadsheet import *

# %%
config_path = '/usr/local/google/home/evgeniyaengel/Documents/onboarding_files/CE/us-mtv-ce_onboard-add-virtual.yaml'
with open(config_path, 'r') as f:
    config = yaml.load(f, Loader=yaml.RoundTripLoader)
    f.close()

# %%
entities = [key for key, val in config.items() if val.get('etag')]

# %%
entities
# Out:
# ['7cb69fba-0acd-437a-a1f2-a7159e216538',
#  '8dcda17b-d605-4838-b74f-8197f3c2c07d',
#  '7d17f647-aaae-4afa-a474-406b6169b355',
#  'ada9ec8c-434d-4bb6-a21f-e53e401f331f',
#  '53117a8b-91e4-4ef5-8bc6-df445d4559f0',
#  'e20b194b-589e-4007-9dca-f6df85aa1387',
#  'd8e75d3c-377a-4df8-853d-e1df2011a579',
#  'bc701515-c981-4a7b-a853-7440c214d823',
#  'b7664ce7-51c1-4f21-9174-77681b910041',
#  '8e5e42de-2ef6-48e9-8398-ee2bce7d035f',
#  '3af2c1c9-05b2-4130-9bdb-423ccdf86c37',
#  'e023fc72-2fdc-4208-ab6d-0d95e83cb74f',
#  'c9786c31-feb6-405b-ac4f-8bed68061d05',
#  '01215d09-d8ba-4313-ad0e-a201027fd425',
#  '3ea469ea-032a-42f3-a28b-e130288866dc',
#  '249115df-528f-4a38-a231-ff08597a0716',
#  'd851ae22-dcb4-4ffd-8dda-77619a71b829',
#  'b5d1123d-1574-4316-b108-56549c1d5f2f',
#  '31ab0fc9-ca80-4da2-ae8d-85073edea7ea',
#  'ece36207-1bf3-4284-a09e-9644be3663d7',
#  '4030cc5c-93b6-48a3-9335-c23df8f5ab0d',
#  '1421f4ca-d646-439e-a181-f2e591ee8ced',
#  'db3bd553-fd81-488d-85f9-bcb79a40f556',
# ...
